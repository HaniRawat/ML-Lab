# %% [markdown]
# <a href="https://colab.research.google.com/github/HaniRawat/ML-Lab/blob/main/ml5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot")
plt.legend()
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color='red', marker='o')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]

plt.bar(categories, values, color='blue')
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Plot")
plt.show()

# %%
data = np.random.randn(1000)

plt.hist(data, bins=30, color='green', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %%
data = [7, 8, 5, 6, 9, 12, 15, 14, 13, 10, 10, 8]

plt.boxplot(data)
plt.title("Box Plot")
plt.show()

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [25, 35, 20, 20]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart")
plt.show()

# %%
import seaborn as sns
import pandas as pd

data = np.random.rand(5,5)
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D', 'E'])

sns.heatmap(df, annot=True, cmap="coolwarm")
plt.title("Heatmap")
plt.show()
